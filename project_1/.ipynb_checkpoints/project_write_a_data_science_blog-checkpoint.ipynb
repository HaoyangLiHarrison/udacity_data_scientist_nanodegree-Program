# %% [markdown]
# # Thinking about hosting Airbnb? A quick peek at Seattle market.

# %% [markdown]
# ## Business questions:
#
# 1. Who are the hosts?
#
# 2. Can hosting generate decent income?
#
# 3. Any secrete sauce of becoming a successful host?

# %% [markdown]
# ## Datasets
#
# Source: *Seattle Airbnb Open Data: https://www.kaggle.com/airbnb/seattle/data#reviews.csv*
#
# 1. Listings:
#   - 3818 rows, each row is an Airbnb listing in Seattle
#   - 92 features such as textual descriptions, address, average review score, etc
#
# 1. Reviews
#   - 84849 rows, each row is a review from a traveller
#   - 6 features such as unique id for each reviewer, detailed comments, etc
#
# 1. Calendar
#   - 1393570 rows, each row is the daily availability of a listing
#   - 4 features such as availability, price , etc

# %% [markdown]
# ## Importing Libraries needed

# %%
# Basic tools
import pandas as pd 
import scipy.stats as ss
import numpy as np
from pandas_profiling import ProfileReport
from collections import Counter

# Plotting tools
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick

# Feature Engineering
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import geopy.distance

# Models
from sklearn.model_selection import train_test_split
import xgboost
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import r2_score, mean_squared_error, roc_auc_score, accuracy_score #metrics
from sklearn.manifold import TSNE
from sklearn.decomposition import TruncatedSVD

from sklearn.feature_selection import SelectKBest 
from sklearn.feature_selection import chi2 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from sklearn.linear_model import SGDClassifier
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %matplotlib inline
sns.set()
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_row', 500)
pd.options.display.float_format = '{:,.2f}'.format

plt.rcParams.update({'figure.max_open_warning': 0})

pd.set_option('mode.chained_assignment', None)

# %% [markdown]
# ## Defining some helper functions

# %%
def remove_constant_col(df):
    ct = 0
    for col in df.columns:
        uni_count = len(df[col].unique())
        nul_count = df[col].isnull().sum()
        nul_perc = nul_count/df.shape[0]
        if (uni_count == 1):
            df.drop(col,axis=1,inplace=True)
            print('{} removed.'.format(col))
            ct+=1
    print('Done. Total of {} columns were removed because they have constant values.'.format(ct))
    return df

def find_correlated_col(df):
    corr_matrix = df.corr().abs()
    high_corr_var = np.where(corr_matrix>0.9)
    high_corr_var = [(corr_matrix.columns[x],corr_matrix.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]
    print(high_corr_var)
    print('Done. Found {} pairs of columns that have above 0.9 correlations.'.format(len(high_corr_var)))
    
def binary_encoding(series,amenity_keyword):
    
    series_encoded = np.where(
        series.str.contains(amenity_keyword,case=False),
        1,
        0
    )
    return series_encoded

def get_unique(series):

    ver_method = []
    listing_no = []
    line_count = 0
    for listing in series.str.split(','):
        line_count +=1
        try:
            for ver in listing:
                ver_method.append(ver)
        except:
                ver_method.append('n/a')
                listing_no.append(line_count)
    print('Total of {} unique values: '.format(len(set(ver_method))))
    print(Counter(ver_method))
    
    return Counter(ver_method)
    

def convert_to_binary(series):

    series= np.where(series.isnull()==False, 1, 0)
    return series

def format_dollar_str(series,df):
    '''
    A helper function to format dollar amount from str to float.
    '''
    df[series] = df[series].str.replace(r'\.00','')
    df[series] = df[series].str.replace(r'[,\$]','')
    df[series] = df[series].astype(float)
    
    return df[series]

def format_timestamp(series,df):
    '''
    A helper function to format timestamp to get days elapsed.
    '''
    df[series] = pd.to_datetime(df[series])
    df[series] = last_day - df[series]
    df[series] = df[series].dt.days
    
    return df[series]

# %% [markdown]
# ## Loading the data

# %%
listings = pd.read_csv('listings.csv')
listings.dropna(subset=['host_name'],axis=0,inplace=True)
listings.sample(2)
# Out:
#            id                           listing_url       scrape_id  \
# 2573  5006092  https://www.airbnb.com/rooms/5006092  20160104002432
# 1618  2978929  https://www.airbnb.com/rooms/2978929  20160104002432
#
#      last_scraped                                name  \
# 2573   2016-01-04  Spacious Studio close to UW campus
# 1618   2016-01-04       Bohemian Studio Near Downtown
#
#                                                 summary  \
# 2573  Spacious, quiet studio retreat in the lovely M...
# 1618  Welcome to my home!  My studio apartment is me...
#
#                                                   space  \
# 2573  Enjoy a tranquil retreat in this private spaci...
# 1618  The bohemian decoration has a mixture of uniqu...
#
#                                             description experiences_offered  \
# 2573  Spacious, quiet studio retreat in the lovely M...                none
# 1618  Welcome to my home!  My studio apartment is me...                none
#
#                                   neighborhood_overview  \
# 2573  Montlake is a lovely neighborhood centrally lo...
# 1618  First Hill is the neighborhood that's within w...
#
#                                                   notes  \
# 2573                                                NaN
# 1618  The apartment handbook will be forwarded appro...
#
#                                                 transit  \
# 2573  - Free on-street parking - One block to bus li...
# 1618  Several buses are within 2 blocks of the apart...
#
#                                           thumbnail_url  \
# 2573  https://a1.muscache.com/ac/pictures/66455349/f...
# 1618  https://a2.muscache.com/ac/pictures/38470151/b...
#
#                                              medium_url  \
# 2573  https://a1.muscache.com/im/pictures/66455349/f...
# 1618  https://a2.muscache.com/im/pictures/38470151/b...
#
#                                             picture_url  \
# 2573  https://a1.muscache.com/ac/pictures/66455349/f...
# 1618  https://a2.muscache.com/ac/pictures/38470151/b...
#
#                                          xl_picture_url   host_id  \
# 2573  https://a1.muscache.com/ac/pictures/66455349/f...  25816390
# 1618  https://a2.muscache.com/ac/pictures/38470151/b...   8838512
#
#                                         host_url host_name  host_since  \
# 2573  https://www.airbnb.com/users/show/25816390  Susannah  2015-01-08
# 1618   https://www.airbnb.com/users/show/8838512     Sarah  2013-09-14
#
#                            host_location  \
# 2573  Seattle, Washington, United States
# 1618  Seattle, Washington, United States
#
#                                              host_about  host_response_time  \
# 2573  A life-long Northwest resident, I have lived i...  within a few hours
# 1618  I am a freelance photographer and videographer...  within a few hours
#
#      host_response_rate host_acceptance_rate host_is_superhost  \
# 2573               100%                 100%                 f
# 1618               100%                 100%                 f
#
#                                      host_thumbnail_url  \
# 2573  https://a1.muscache.com/ac/users/25816390/prof...
# 1618  https://a0.muscache.com/ac/users/8838512/profi...
#
#                                        host_picture_url host_neighbourhood  \
# 2573  https://a1.muscache.com/ac/users/25816390/prof...           Montlake
# 1618  https://a0.muscache.com/ac/users/8838512/profi...         First Hill
#
#       host_listings_count  host_total_listings_count  \
# 2573                 1.00                       1.00
# 1618                 1.00                       1.00
#
#                                     host_verifications host_has_profile_pic  \
# 2573                     ['email', 'phone', 'reviews']                    t
# 1618  ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
#
#      host_identity_verified  \
# 2573                      f
# 1618                      t
#
#                                                  street neighbourhood  \
# 2573  23rd Avenue East, Seattle, WA 98112, United St...      Montlake
# 1618       9th Avenue, Seattle, WA 98104, United States    First Hill
#
#      neighbourhood_cleansed neighbourhood_group_cleansed     city state  \
# 2573               Montlake                 Capitol Hill  Seattle    WA
# 1618             First Hill                     Downtown  Seattle    WA
#
#      zipcode   market smart_location country_code        country  latitude  \
# 2573   98112  Seattle    Seattle, WA           US  United States     47.64
# 1618   98104  Seattle    Seattle, WA           US  United States     47.61
#
#       longitude is_location_exact property_type        room_type  \
# 2573    -122.30                 t     Apartment  Entire home/apt
# 1618    -122.33                 t     Apartment  Entire home/apt
#
#       accommodates  bathrooms  bedrooms  beds  bed_type  \
# 2573             2       1.00      1.00  1.00  Real Bed
# 1618             3       1.00      0.00  1.00  Real Bed
#
#                                               amenities  square_feet    price  \
# 2573  {TV,"Cable TV",Internet,"Wireless Internet",Ki...          nan  $125.00
# 1618  {Internet,"Wireless Internet",Kitchen,"Free Pa...          nan  $100.00
#
#      weekly_price monthly_price security_deposit cleaning_fee  \
# 2573      $775.00           NaN              NaN       $40.00
# 1618      $800.00     $3,280.00          $250.00       $60.00
#
#       guests_included extra_people  minimum_nights  maximum_nights  \
# 2573                1        $0.00               2              14
# 1618                1       $15.00               2             100
#
#      calendar_updated has_availability  availability_30  availability_60  \
# 2573      2 weeks ago                t               20               20
# 1618      3 weeks ago                t               25               55
#
#       availability_90  availability_365 calendar_last_scraped  \
# 2573               40               129            2016-01-04
# 1618               84                84            2016-01-04
#
#       number_of_reviews first_review last_review  review_scores_rating  \
# 2573                 29   2015-04-09  2015-12-07                 96.00
# 1618                 45   2014-05-28  2015-10-10                 89.00
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 2573                   10.00                      10.00
# 1618                   10.00                       9.00
#
#       review_scores_checkin  review_scores_communication  \
# 2573                  10.00                        10.00
# 1618                   9.00                         9.00
#
#       review_scores_location  review_scores_value requires_license  license  \
# 2573                   10.00                 9.00                f      nan
# 1618                    9.00                 8.00                f      nan
#
#      jurisdiction_names instant_bookable cancellation_policy  \
# 2573         WASHINGTON                f            moderate
# 1618         WASHINGTON                t              strict
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 2573                             f                                f
# 1618                             f                                f
#
#       calculated_host_listings_count  reviews_per_month
# 2573                               1               3.21
# 1618                               1               2.30

# %%
listings.shape
# Out:
# (3816, 92)

# %%
reviews = pd.read_csv('reviews.csv')
reviews.date = pd.to_datetime(reviews.date)
reviews.sample(2)
# Out:
#        listing_id        id        date  reviewer_id reviewer_name  \
# 47115     1321090  50271446  2015-10-11     19011795          Jill
# 67009      699460   6180204  2013-08-02      7432732         Chris
#
#                                                 comments
# 47115  Such a wonderful experience. Could not have st...
# 67009  Patti is a conscientious and responsive host. ...

# %%
reviews.date.min()
# Out:
# Timestamp('2009-06-07 00:00:00')

# %%
reviews.date.max()
# Out:
# Timestamp('2016-01-03 00:00:00')

# %%
calendar = pd.read_csv('calendar.csv')
calendar.price = calendar.price.str.replace(r'\.00','')
calendar.price = calendar.price.str.replace(r'[$,]','')
calendar.price = calendar.price.astype(float) 
last_day = pd.to_datetime(calendar.date.max())
calendar.sample(2)
# Out:
#         listing_id        date available  price
# 805365     4832481  2016-06-27         t  57.00
# 939428     5006092  2016-10-13         f    nan

# %%
 calendar.shape
# Out:
# (1393570, 4)

# %% [markdown]
# ## Pre-processing

# %%
listings = remove_constant_col(listings)
# Out:
# scrape_id removed.
# last_scraped removed.
# experiences_offered removed.
# market removed.
# country_code removed.
# country removed.
# has_availability removed.
# calendar_last_scraped removed.
# requires_license removed.
# license removed.
# jurisdiction_names removed.
# Done. Total of 11 columns were removed because they have constant values.

# %%
reviews = remove_constant_col(reviews)
# Out:
# Done. Total of 0 columns were removed because they have constant values.

# %%
calendar = remove_constant_col(calendar)
# Out:
# Done. Total of 0 columns were removed because they have constant values.

# %%
find_correlated_col(listings)
# Out:
# [('host_listings_count', 'host_total_listings_count'), ('availability_30', 'availability_60'), ('availability_60', 'availability_90')]
# Done. Found 3 pairs of columns that have above 0.9 correlations.

# %%
listings.drop('host_total_listings_count',axis=1,inplace=True)

# %%
find_correlated_col(reviews)
# Out:
# []
# Done. Found 0 pairs of columns that have above 0.9 correlations.

# %%
find_correlated_col(calendar)
# Out:
# []
# Done. Found 0 pairs of columns that have above 0.9 correlations.

# %% [markdown]
# ^ host_listings_count and host_total_listings_count are basically identical except 2 nulls. Simply removing 1 of them. availability_30, 60, and 90 are sort of expected to have high correlation, so keeping them all for now.

# %% [markdown]
# Amenity and host_verifications column are a little bit tricky.
#
# For amenity, 4 new columns are generated. The amenities_counts counts how many amenities were listed. 3 additional features each are binary to describe if something is listed. I chose my personal 3 most wanted feature.The reason I didn't simply use the binary encoding method for all features is to avoid creating too many dimensions at the early stage of the project given how many unique amenities are out there.
#
# For host_verifications, since most hosts have been verified using email, phone, or reviews, and some have additional verifications, so let's reflect that by a host_verifications_counts feature.

# %%
# removing columns of urls and non-helpful values such as state and city
listings = listings[listings.columns[listings.columns.str.contains('url')==False]]
listings = listings.drop([
    'city',
    'host_acceptance_rate',
    'smart_location',
    'state'
],axis=1)

# %% [markdown]
# ## Null values handling

# %%
sns.set();
f, axes = plt.subplots(1, 3, figsize=(12, 8), sharex=False, sharey=False)

listings_null_row = listings.isnull().sum()
reviews_null_row = reviews.isnull().sum()
calendar_null_row = calendar.isnull().sum()

color_palette_list = sns.color_palette('muted')
hist_kws={
        "rwidth":0.15
    }

sns.distplot(
    listings_null_row,
    kde=False,
    rug=False,
    ax=axes[0],
    color=color_palette_list[0], 
    label = 'listings'
)
sns.distplot(
    reviews_null_row, 
    kde=False,
    rug=False,
    ax=axes[1],
    color=color_palette_list[1],
    label = 'reviews',
    hist_kws={
        "rwidth":0.1
    }
)
sns.distplot(
    calendar_null_row, 
    kde=False,
    rug=False,
    ax=axes[2],
    color=color_palette_list[2], 
    label = 'calendar',
    hist_kws={
        "rwidth":0.2
    }
)

axes[0].set_xlabel('Listings dataframe')
axes[1].set_xlabel('Revewis dataframe')
axes[2].set_xlabel('Calendar dataframe')
axes[0].set_ylabel('Frequency of columns')

axes[0].legend()
axes[1].legend()
axes[2].legend()

f.suptitle('Null value Counts of each column in 3 datasets');

# %%
listings.isnull().sum()[listings.isnull().sum()>0].sort_values(ascending=False)
# Out:
# square_feet                    3719
# monthly_price                  2300
# security_deposit               1950
# weekly_price                   1809
# notes                          1605
# neighborhood_overview          1031
# cleaning_fee                   1029
# transit                         933
# host_about                      857
# review_scores_checkin           656
# review_scores_accuracy          656
# review_scores_value             654
# review_scores_location          653
# review_scores_cleanliness       651
# review_scores_communication     649
# review_scores_rating            645
# reviews_per_month               625
# first_review                    625
# last_review                     625
# space                           568
# host_response_rate              521
# host_response_time              521
# neighbourhood                   416
# host_neighbourhood              298
# summary                         177
# bathrooms                        16
# zipcode                           7
# host_location                     6
# bedrooms                          6
# property_type                     1
# beds                              1
# dtype: int64

# %%
# Droppng square_feet because of too many nulls 
listings.drop('square_feet',axis=1,inplace=True)

# %%
# Assuming null values for 'security_deposit','cleaning_fee' means no charges
listings[['security_deposit','cleaning_fee']] = listings[['security_deposit','cleaning_fee']].fillna(value='$0')

# %%
# Converting columns that have above 700 nulls to binary.
to_bina = listings.isnull().sum()[listings.isnull().sum()>700]
for col in to_bina.index.values:
    listings[col] = convert_to_binary(listings[col])

# %%
# Identify low cardinal columns 
# Transfering binary columns that are nomimal to numeric

listings_temp = listings.copy()
low_cardinality_col = []
binary_col = []
for col in listings_temp.columns:
    unique_count = len(listings[col].unique())
    if 2 < unique_count < 10:
        low_cardinality_col.append(col)
    if unique_count == 2:
        binary_col.append(col)
    
listings_temp.dtypes.value_counts()
# Out:
# object     35
# int64      18
# float64    14
# dtype: int64

# %%
# Taking a closer look at nulls due to no reviews recorded 
review_col = listings.columns[listings.columns.str.contains('review')]
listings[listings.number_of_reviews==0][review_col].drop(
    ['number_of_reviews'],axis=1).isnull().sum()
# Out:
# first_review                   625
# last_review                    625
# review_scores_rating           625
# review_scores_accuracy         625
# review_scores_cleanliness      625
# review_scores_checkin          625
# review_scores_communication    625
# review_scores_location         625
# review_scores_value            625
# reviews_per_month              625
# dtype: int64

# %%
listings = listings[listings.number_of_reviews!=0]
listings.reset_index(drop=True,inplace=True)

# %%
# fill na for response_time and rate
listings.host_response_time = listings.host_response_time.fillna('never')
listings.host_response_rate = listings.host_response_rate.fillna('0%')
listings.host_response_rate = listings.host_response_rate.str.extract(r'(\d+)\%')

# %%
# simply fill na with strings for the 2 textual features
simply_fill = [
    'space',
    'summary',
    'neighbourhood',
    'host_neighbourhood',
    'host_location',
    'zipcode',
    ]
listings[simply_fill] = listings[simply_fill].fillna(value='n/a')

# %%
listings.isnull().sum()[listings.isnull().sum()>0].sort_values(ascending=False)
# Out:
# review_scores_checkin          31
# review_scores_accuracy         31
# review_scores_value            29
# review_scores_location         28
# review_scores_cleanliness      26
# review_scores_communication    24
# review_scores_rating           20
# bathrooms                      12
# bedrooms                        6
# dtype: int64

# %%
# Impute the only listing without property_type w/ most common value
listings.property_type = listings.property_type.fillna('House')

# Impute the rest numberical columns with means
to_impute = listings.isnull().sum()[listings.isnull().sum()>0].sort_values(ascending=False).index

imp_mode = SimpleImputer(missing_values=np.nan, strategy='mean')
listings_imputed = pd.DataFrame(imp_mode.fit_transform(listings[to_impute]))

listings_imputed.columns = listings[to_impute].columns
listings_imputed.index = listings[to_impute].index
for x in listings[to_impute].columns:
    listings_imputed[x]=listings_imputed[x].astype(listings[to_impute][x].dtypes.name)
listings[to_impute] = listings_imputed
listings_imputed = listings.copy()
listings_imputed.shape,listings.shape
# Out:
# ((3191, 67), (3191, 67))

# %%
# Imputing null price with its average price in 2016 
calendar_imputed = calendar.copy()
calendar_imputed["price"] = calendar_imputed.groupby("listing_id").transform(lambda x: x.fillna(x.mean()))

# For listings that shown as avaliable throughout 2016, imputing their prices 
# with the average price of the Seatle region  
calendar_imputed["price"].fillna(calendar_imputed.price.mean(),inplace=True)
calendar_imputed.sample(5)
# Out:
#          listing_id        date available  price
# 386855       879181  2016-11-19         t  65.00
# 786948      3372535  2016-01-12         f  45.39
# 746844       587584  2016-02-27         t  99.00
# 958953      2488228  2016-04-11         f  82.07
# 1010202     1686958  2016-09-07         t 130.00

# %%
# Null handelling is done for listing dataset
listings_imputed.isnull().sum().value_counts()
# Out:
# 0    67
# dtype: int64

# %%
# Null handelling is done for reviews dataset
reviews_imputed = reviews.fillna('n/a')
reviews_imputed.isnull().sum().value_counts()
# Out:
# 0    6
# dtype: int64

# %%
# Null handelling is done for calendar dataset
calendar_imputed.isnull().sum().value_counts()
# Out:
# 0    4
# dtype: int64

# %% [markdown]
# ## Additional pre-processing

# %%
listings_imputed.amenities = listings_imputed.amenities.replace('{}',np.nan)
listings_imputed.amenities =listings_imputed.amenities.str.replace(r'[\{\}"]', '')
amentities_counter = get_unique(listings_imputed.amenities)

listings_imputed['amenities_counts'] = listings_imputed.amenities.str.split(',').str.len()
listings_imputed['amenities_counts'] = listings_imputed['amenities_counts'].fillna(0)

# survey shows the following are the most wanted amenties in the US (2)
most_wanted_amenities= [
    'Air Conditioning',
    'Free Parking on Premises',
    'Pets Allowed',
    'pool',
    'Kitchen'
]

# encoding the non nulls to 1 and nulls to 0 
for ame in most_wanted_amenities:
     listings_imputed[ame]= binary_encoding(listings_imputed.amenities,ame)

listings_imputed.drop('amenities',axis=1,inplace=True)

listings_imputed.host_verifications = listings_imputed.host_verifications.str.replace(r"[\[\]']", '').str.replace(r', ',',').replace(r'None',np.nan).replace('',np.nan)
host_verifications_counter = get_unique(listings_imputed.host_verifications)

listings_imputed['host_verifications_counts'] = listings_imputed.host_verifications.str.split(',').str.len()
listings_imputed['host_verifications_counts'] = listings_imputed['host_verifications_counts'].fillna(0)

established_verifications = [
    'kba',
    'jumio'
]

# encoding the non nulls to 1 and nulls to 0 
for host_v in established_verifications:
     listings_imputed[host_v]= binary_encoding(listings_imputed.host_verifications,host_v)

listings_imputed.drop('host_verifications',axis=1,inplace=True)
# Out:
# Total of 42 unique values:
# Counter({'Wireless Internet': 3097, 'Heating': 3062, 'Kitchen': 2879, 'Smoke Detector': 2780, 'Essentials': 2739, 'Dryer': 2509, 'Washer': 2500, 'Internet': 2395, 'Shampoo': 2296, 'TV': 2158, 'Carbon Monoxide Detector': 2122, 'Fire Extinguisher': 1859, 'Free Parking on Premises': 1846, 'Family/Kid Friendly': 1681, 'First Aid Kit': 1442, 'Cable TV': 1228, 'Pets live on this property': 758, 'Indoor Fireplace': 742, 'Elevator in Building': 652, 'Hangers': 635, 'Safety Card': 624, 'Hair Dryer': 605, 'Iron': 581, 'Air Conditioning': 564, 'Laptop Friendly Workspace': 547, '24-Hour Check-in': 460, 'Buzzer/Wireless Intercom': 458, 'Dog(s)': 434, 'Pets Allowed': 399, 'Gym': 357, 'Cat(s)': 329, 'Wheelchair Accessible': 255, 'Hot Tub': 249, 'Breakfast': 249, 'Suitable for Events': 186, 'Pool': 141, 'Smoking Allowed': 69, 'Doorman': 68, 'Lock on Bedroom Door': 53, 'Other pet(s)': 44, 'n/a': 23, 'Washer / Dryer': 1})
# Total of 14 unique values:
# Counter({'reviews': 3187, 'phone': 3175, 'email': 3128, 'facebook': 1643, 'kba': 1611, 'jumio': 1102, 'linkedin': 760, 'google': 630, 'manual_offline': 43, 'amex': 21, 'manual_online': 12, 'sent_id': 7, 'photographer': 4, 'weibo': 4})

# %%
# Transforming timestamp str to days in interger 
listings_imputed['host_since'] =  format_timestamp('host_since',listings_imputed)
listings_imputed['first_review'] =  format_timestamp('first_review',listings_imputed)
listings_imputed['last_review'] =  format_timestamp('last_review',listings_imputed)

# Transforming dollar amount str to interger 
for col in listings_imputed.select_dtypes('object').columns:
    dollar_sign_count = listings_imputed[col].str.contains(r'\$\d+').sum()
    if dollar_sign_count == listings_imputed.shape[0]:
        listings_imputed[col] = format_dollar_str(col,listings_imputed)

# Dropping the price column from listing dataframe because we alreay have it 
listings_imputed.drop('price',axis=1,inplace=True)

# Changing the possible typo of the zipcode  
listings_imputed.zipcode = listings_imputed.zipcode.str.replace('99\n98122','98122')

# %%
# mapping hosts to listings with info of NO. of nights available
grouped_listing = calendar_imputed.groupby(['listing_id','available']).price.value_counts()
temp = grouped_listing[grouped_listing.index.isin(['f'], level=1)]
performance = pd.DataFrame(
    columns=['listing_id','nights_unavailable','nights_available','estimated_price'],
    data={
        'listing_id' : temp.index.get_level_values(0),
        'nights_unavailable' : temp.values,
        'nights_available' : 365 - temp.values,
        'estimated_price' : temp.index.get_level_values(2)
    }
    
)
performance = performance.merge(calendar_imputed,on='listing_id',how='inner').fillna(0).drop_duplicates(subset='listing_id')
performance.drop(['price','available','date'],axis=1,inplace=True)

# temp listing copy for inner join
listings_1 = listings_imputed.copy()
listings_1['listing_id'] = listings_1['id'].copy()
performance = performance.merge(listings_1[['host_id','listing_id']],on='listing_id',how='inner')

# calculating the estimated income of a listing 
performance['nights_available'] = performance['nights_available'].astype(int)
performance['estimated_price'] = performance['estimated_price'].astype(int)
performance = performance[[
    'listing_id',
    'host_id',
    'nights_unavailable', 
    'nights_available',
    'estimated_price',
]]
listings_imputed.rename({'id':'listing_id'},axis=1,inplace=True)
listings_performance = performance.merge(listings_imputed.drop('host_id',axis=1),on='listing_id',how='inner')

# according to airbnb about 33% (3) of guests eneded up leaving a review  
listings_performance['estimated_bookings'] = listings_performance.number_of_reviews / 0.33
listings_performance['estimated_income'] = listings_performance['estimated_bookings'] * listings_performance['estimated_price']

listings_performance['host_in_wa'] = np.where(
    listings_performance.host_location.str.contains(r'seattle|Washington, United States|Washington State',case=False),
    1,
    0
)

pike_place = (47.609657, -122.342148)
listings_performance['lat_long'] = list(zip(listings_performance.latitude, listings_performance.longitude))
listings_performance['distance_from_pp'] = listings_performance.lat_long.apply(lambda x: geopy.distance.geodesic(pike_place, x).miles)

listings_performance.calendar_updated.replace(
    {
        'today' : '0 day ago',
        'yesterday' : '1 day ago',
        'a week ago' : '1 week ago',
    },inplace=True
)
listings_performance['calendar_updated_months'] = listings_performance.calendar_updated.str.extract(r'(.*)\s+months?').fillna(0).astype(int)
listings_performance['calendar_updated_weeks'] = listings_performance.calendar_updated.str.extract(r'(.*)\s+weeks?').fillna(0).astype(int)
listings_performance['calendar_updated_days'] = listings_performance.calendar_updated.str.extract(r'(.*)\s+days?').fillna(0).astype(int)
listings_performance['calendar_updated_count'] = listings_performance.calendar_updated_months*30 + listings_performance.calendar_updated_weeks*7 + listings_performance.calendar_updated_days
listings_performance['calendar_updated_count'] = np.where(
    listings_performance.calendar_updated=='never',
    listings_performance.host_since,
    listings_performance.calendar_updated_count
)

listings_performance['cancellation_policy'] = listings_performance['cancellation_policy'].replace(
    {
        'flexible':1, 
        'moderate':2,
        'strict':3
    }
)
listings_performance.sample(3)
# Out:
#       listing_id   host_id  nights_unavailable  nights_available  \
# 2067     7678064  36057637                 192               173
# 382      1328159   7207028                  11               354
# 2570     9233533    469819                   5               360
#
#       estimated_price                                 name  \
# 2067              323    Spacious Seattle Center Townhouse
# 382                49  Queen Bedroom in House West Seattle
# 2570               95      Welcoming & Refined Garden Apt.
#
#                                                 summary  \
# 2067  Spacious, modern 3bd/3.5ba townhouse just step...
# 382   A private room & bath with full kitchen access...
# 2570  Charming & pretty one bedroom mother-in-law ap...
#
#                                                   space  \
# 2067  Spectacular 360 degree views are great...if yo...
# 382   3 Bedroom - 2 1/2 Bath  Half of a duplex - tid...
# 2570  This is a beautiful, mother-in-law apartment o...
#
#                                             description  \
# 2067  Spacious, modern 3bd/3.5ba townhouse just step...
# 382   A private room & bath with full kitchen access...
# 2570  Charming & pretty one bedroom mother-in-law ap...
#
#       neighborhood_overview  notes  transit host_name  host_since  \
# 2067                      1      1        1    Martha         565
# 382                       1      0        1      John        1282
# 2570                      1      1        1      Tina        2106
#
#                            host_location  host_about host_response_time  \
# 2067  Seattle, Washington, United States           1     within an hour
# 382   Seattle, Washington, United States           1     within an hour
# 2570  Seattle, Washington, United States           1     within an hour
#
#      host_response_rate host_is_superhost host_neighbourhood  \
# 2067                100                 f   Lower Queen Anne
# 382                 100                 f     North Delridge
# 2570                100                 f      Olympic Hills
#
#       host_listings_count host_has_profile_pic host_identity_verified  \
# 2067                 4.00                    t                      t
# 382                  1.00                    t                      t
# 2570                 1.00                    t                      f
#
#                                                  street     neighbourhood  \
# 2067  6th Avenue North, Seattle, WA 98109, United St...  Lower Queen Anne
# 382   Southwest Adams Street, Seattle, WA 98126, Uni...    North Delridge
# 2570  Northeast 127th Street, Seattle, WA 98125, Uni...     Olympic Hills
#
#      neighbourhood_cleansed neighbourhood_group_cleansed zipcode  latitude  \
# 2067       Lower Queen Anne                   Queen Anne   98109     47.63
# 382          North Delridge                     Delridge   98126     47.56
# 2570          Olympic Hills                    Lake City   98125     47.72
#
#       longitude is_location_exact property_type        room_type  \
# 2067    -122.34                 t     Townhouse  Entire home/apt
# 382     -122.37                 t         House     Private room
# 2570    -122.31                 t     Apartment  Entire home/apt
#
#       accommodates  bathrooms  bedrooms  beds  bed_type  weekly_price  \
# 2067             6       3.50      3.00  5.00  Real Bed             1
# 382              2       2.50      1.00  1.00  Real Bed             0
# 2570             2       1.00      1.00  1.00  Real Bed             0
#
#       monthly_price  security_deposit  cleaning_fee  guests_included  \
# 2067              0            400.00        210.00                6
# 382               0              0.00         10.00                1
# 2570              0              0.00         25.00                2
#
#       extra_people  minimum_nights  maximum_nights calendar_updated  \
# 2067         35.00               3            1125        0 day ago
# 382          10.00               1              21       2 days ago
# 2570         15.00               1            1125      6 weeks ago
#
#       availability_30  availability_60  availability_90  availability_365  \
# 2067               25               55               84               173
# 382                30               49               79               354
# 2570               25               55               85               360
#
#       number_of_reviews  first_review  last_review  review_scores_rating  \
# 2067                  3           441          370                100.00
# 382                  57          1265          394                 98.00
# 2570                  3           413          401                100.00
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 2067                   10.00                      10.00
# 382                    10.00                      10.00
# 2570                   10.00                      10.00
#
#       review_scores_checkin  review_scores_communication  \
# 2067                  10.00                        10.00
# 382                   10.00                        10.00
# 2570                  10.00                        10.00
#
#       review_scores_location  review_scores_value instant_bookable  \
# 2067                   10.00                10.00                f
# 382                    10.00                10.00                f
# 2570                    9.00                10.00                f
#
#       cancellation_policy require_guest_profile_picture  \
# 2067                    3                             f
# 382                     1                             f
# 2570                    1                             f
#
#      require_guest_phone_verification  calculated_host_listings_count  \
# 2067                                f                               4
# 382                                 f                               1
# 2570                                f                               1
#
#       reviews_per_month  amenities_counts  Air Conditioning  \
# 2067               1.15             14.00                 0
# 382                1.90             15.00                 0
# 2570               1.80             19.00                 0
#
#       Free Parking on Premises  Pets Allowed  pool  Kitchen  \
# 2067                         1             0     0        1
# 382                          0             0     0        1
# 2570                         1             0     0        1
#
#       host_verifications_counts  kba  jumio  estimated_bookings  \
# 2067                          6    1      0                9.09
# 382                           5    1      0              172.73
# 2570                          4    0      0                9.09
#
#       estimated_income  host_in_wa                                  lat_long  \
# 2067          2,936.36           1  (47.62607559607521, -122.34450403862124)
# 382           8,463.64           1  (47.56458426665185, -122.36630909477064)
# 2570            863.64           1  (47.72043752479437, -122.30858457320112)
#
#       distance_from_pp  calendar_updated_months  calendar_updated_weeks  \
# 2067              1.14                        0                       0
# 382               3.31                        0                       0
# 2570              7.81                        0                       6
#
#       calendar_updated_days  calendar_updated_count
# 2067                      0                       0
# 382                       2                       2
# 2570                      0                      42

# %%
# calculate NO. of nights unavailable on host level across all listings owned
grouped = listings_performance.groupby('host_id')
hosts = pd.DataFrame(
    columns=[
        'listings_owned',
        'estimated_bookings',
        'estimated_income',
        'number_of_reviews'
    ],
    data={
        'listings_owned' : grouped.estimated_bookings.size(),
        'estimated_bookings' : grouped.estimated_bookings.sum(),
        'estimated_income' : grouped.estimated_income.sum(),
        'number_of_reviews' : grouped.number_of_reviews.sum()
         }
)

hosts.reset_index(drop=False,inplace=True)
lp_to_join = listings_performance[[
    'host_id',
    'host_name',
    'host_since',
    'host_location',
    'host_about',
    'host_is_superhost',
    'host_neighbourhood',
    'host_listings_count',
    'host_has_profile_pic',
    'host_identity_verified'
]].drop_duplicates(subset='host_id')
hosts = hosts.merge(lp_to_join,on='host_id',how='inner')
hosts['host_in_seattle'] = np.where(
    hosts.host_location.str.contains('Seattle',case=False) | 
    hosts.host_neighbourhood.isin(listings_performance.neighbourhood_cleansed.unique()),
    1,
    0
)
tf_dict = {'f':0,'t':1}
hosts = hosts.replace({"host_is_superhost": tf_dict})
hosts = hosts.replace({"host_has_profile_pic": tf_dict})
hosts = hosts.replace({"host_identity_verified": tf_dict})
hosts.sample(5)
# Out:
#        host_id  listings_owned  estimated_bookings  estimated_income  \
# 1305  19928221               1              530.30         36,590.91
# 1518  26138574               1               24.24          2,400.00
# 111     476303               1               90.91          4,545.45
# 1888  42419614               1               30.30          2,727.27
# 550    4630668               1              260.61         35,181.82
#
#       number_of_reviews     host_name  host_since  \
# 1305                175        Debbie         874
# 1518                  8          Mark         718
# 111                  30         Carol        2104
# 1888                 10         Chase         497
# 550                  86  Kate & Danny        1455
#
#                            host_location  host_about  host_is_superhost  \
# 1305  Seattle, Washington, United States           1                  1
# 1518  Seattle, Washington, United States           0                  0
# 111   Seattle, Washington, United States           1                  0
# 1888                                  US           0                  0
# 550   Seattle, Washington, United States           1                  0
#
#      host_neighbourhood  host_listings_count  host_has_profile_pic  \
# 1305            Ballard                 1.00                     1
# 1518                n/a                 1.00                     1
# 111             Ballard                 1.00                     1
# 1888         First Hill                 1.00                     1
# 550             Ballard                 1.00                     1
#
#       host_identity_verified  host_in_seattle
# 1305                       1                1
# 1518                       1                1
# 111                        1                1
# 1888                       0                1
# 550                        1                1

# %% [markdown]
# ## 1. Who are the hosts?
#     - multi-hosts vs single hosts
#     - gender of the hosts
#     - local vs remote hosts
#     - superhosts vs the rest
#     - typical # of listings owned
#     - property types of the listings

# %% [markdown]
# ### multi-hosts vs single hosts
# 90% of hosts are single hosts, and the rest 10% are multi-hosts/co-hosts who seem to have:
# - higher percentage of superhosts
# - higher number of reviews for their listsings

# %%
hosts.host_name = hosts.host_name.str.replace(r'&|\+',',')
hosts.host_name = hosts.host_name.str.replace(r'\bAnd\b',',')
hosts.host_name = hosts.host_name.str.replace(r'([a-z])/([a-zA-z])','(1),(2)')
hosts.host_name = hosts.host_name.str.replace('[\(\)]','')
hosts.host_name = hosts.host_name.str.replace(r'\s+',' ')
hosts.host_name = hosts.host_name.str.replace(r'\s?,\s?',',')
hosts['host_count'] = [len(name) for name in hosts.host_name.str.split(',')]
hosts['host_count'].describe()
# Out:
# count   1,996.00
# mean        1.11
# std         0.32
# min         1.00
# 25%         1.00
# 50%         1.00
# 75%         1.00
# max         4.00
# Name: host_count, dtype: float64

# %%
fig, ax = plt.subplots()
labels = [ 
    'single hosts',
    'co-hosts'
]
percentages = [
    1-hosts[hosts.host_count>1].shape[0]/hosts.shape[0], 
    hosts[hosts.host_count>1].shape[0]/hosts.shape[0]
]
explode=(0.1,0)
ax.pie(percentages, explode=explode, labels=labels,  
       colors=[color_palette_list[7],color_palette_list[0]], autopct='%1.0f%%', 
       shadow=False, startangle=0,   
       pctdistance=1.2,labeldistance=1.4)
ax.axis('equal')
ax.set_title("Hosts Ownership")
ax.legend(frameon=True, bbox_to_anchor=(1,1));

# %%
multi_hosts = hosts[hosts.host_count>1]
multi_hosts.shape[0]/hosts.shape[0]
# Out:
# 0.10220440881763528

# %%
single_hosts = hosts[hosts.host_count == 1]
multi_hosts.number_of_reviews.mean(), single_hosts.number_of_reviews.mean()
# Out:
# (54.10294117647059, 35.68359375)

# %%
multi_hosts.host_is_superhost.value_counts(normalize=True)
# Out:
# 0   0.64
# 1   0.36
# Name: host_is_superhost, dtype: float64

# %%
single_hosts.host_is_superhost.value_counts(normalize=True)
# Out:
# 0   0.77
# 1   0.23
# Name: host_is_superhost, dtype: float64

# %% [markdown]
# ### gender of the hosts
# 58% of hosts are females hosts, and 42% are male hosts based on their first names. And 2 groups of hosts have similar performance in terms of number_of_reviews and percentage of superhosts.

# %%
# Obtained common firstname and likeliyhood of gender associated from (1)
name_gender = pd.read_csv('name_gender.csv')
name_gender_dict = dict(zip(name_gender.name, name_gender.gender))
name_gender.head(2)
# Out:
#     name gender  probability
# 0  Aaban      M         1.00
# 1  Aabha      F         1.00

# %%
hosts_1 = hosts.copy()
hosts_1['gender'] = hosts_1.replace({"host_name" : name_gender_dict}).host_name

# %%
# Only considering common English names and single hosts
hosts_1 = hosts_1[hosts_1.gender.isin(['F','M'])]
hosts_1.reset_index(drop=True,inplace=True)

# %%
fig, ax = plt.subplots()
labels = [ 
    'Male Hosts',
    'Female Hosts'
]
percentages = [
    1-hosts_1[hosts_1.gender=='F'].shape[0]/hosts_1.shape[0], 
    hosts_1[hosts_1.gender=='F'].shape[0]/hosts_1.shape[0]
]
explode=(0.1,0)
ax.pie(percentages, explode=explode, labels=labels,  
       colors=[color_palette_list[7],color_palette_list[0]], autopct='%1.0f%%', 
       shadow=False, startangle=-30,   
       pctdistance=1.2,labeldistance=1.4)
ax.axis('equal')
ax.set_title("Gender of the Hosts")
ax.legend(frameon=True, bbox_to_anchor=(1,1));

# %%
hosts_1.groupby('gender').number_of_reviews.mean()
# Out:
# gender
# F   36.11
# M   34.63
# Name: number_of_reviews, dtype: float64

# %%
hosts_1.groupby('gender').host_is_superhost.value_counts(normalize=True)
# Out:
# gender  host_is_superhost
# F       0                   0.77
#         1                   0.23
# M       0                   0.77
#         1                   0.23
# Name: host_is_superhost, dtype: float64

# %% [markdown]
# ### local vs remote hosts
# 96% of hosts are based in Seattle, and the local hosts seem to be more successful because of
# - higher percentage of superhosts
# - higher number of reviews for their listings

# %%
fig, ax = plt.subplots()
labels = ['hosts in Seattle', 
         'hosts outside of Seattle']
percentages = [
    hosts[hosts.host_in_seattle==1].shape[0]/hosts.shape[0], 
    1-hosts[hosts.host_in_seattle==1].shape[0]/hosts.shape[0]
]
explode=(0.1,0)
ax.pie(percentages, explode=explode, labels=labels,  
       colors=[color_palette_list[7],color_palette_list[0]], autopct='%1.0f%%', 
       shadow=False, startangle=0,   
       pctdistance=1.2,labeldistance=1.4)
ax.axis('equal')
ax.set_title("Locations of the Hosts")
ax.legend(frameon=True, bbox_to_anchor=(1,1));

# %%
hosts.groupby('host_in_seattle').host_is_superhost.value_counts(normalize=True)
# Out:
# host_in_seattle  host_is_superhost
# 0                0                   0.88
#                  1                   0.12
# 1                0                   0.75
#                  1                   0.25
# Name: host_is_superhost, dtype: float64

# %%
name_gender.shape
# Out:
# (95026, 3)

# %%
name_gender.gender.value_counts(normalize=True)
# Out:
# F   0.63
# M   0.37
# Name: gender, dtype: float64

# %%
hosts.groupby('host_in_seattle').number_of_reviews.mean()
# Out:
# host_in_seattle
# 0   14.58
# 1   38.43
# Name: number_of_reviews, dtype: float64

# %% [markdown]
# ### superhosts vs the rest
# 24% of hosts are "superhosts" (4), and the superhosts seem to have higher number of reviews.

# %%
fig, ax = plt.subplots()
color_palette_list = sns.color_palette()
labels = ['non-superhost', 
         'superhost']
percentages = [
    hosts[hosts.host_is_superhost==0].shape[0]/hosts.shape[0], 
    1-hosts[hosts.host_is_superhost==0].shape[0]/hosts.shape[0]
]
explode=(0.1,0)
ax.pie(percentages, explode=explode, labels=labels,  
       colors=[color_palette_list[7],color_palette_list[0]], autopct='%1.0f%%', 
       shadow=False, startangle=0,   
       pctdistance=1.2,labeldistance=1.4)
ax.axis('equal')
ax.set_title("Superhosts status")
ax.legend(frameon=True, bbox_to_anchor=(1,1));

# %%
hosts.groupby('host_is_superhost').number_of_reviews.mean()
# Out:
# host_is_superhost
# 0   29.77
# 1   62.06
# Name: number_of_reviews, dtype: float64

# %% [markdown]
# ### typical # of listings owned
# The average listing ownership count is 1.34, so in another word most hosts in Seattle own 1 Airbnb listing. Intuitively, for hosts who have more than 1 listings, the average of number of reviews is 4 times higher.

# %%
hosts.listings_owned.describe()
# Out:
# count   1,996.00
# mean        1.34
# std         1.75
# min         1.00
# 25%         1.00
# 50%         1.00
# 75%         1.00
# max        37.00
# Name: listings_owned, dtype: float64

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8), sharex=False, sharey=False)
ax = sns.regplot(
    x="listings_owned",
    y="number_of_reviews",
    data=hosts,
    marker="D",
    x_jitter=True,
    logx=True,
    label='hosts',
    scatter_kws={'alpha':0.4}
)
ax.legend(frameon=True, bbox_to_anchor=(1,1))
ax.set_title('Listings owned(count) & number of reviews', fontsize=14);

# %%
hosts[hosts.listings_owned==1].host_is_superhost.value_counts(normalize=True)
# Out:
# 0   0.77
# 1   0.23
# Name: host_is_superhost, dtype: float64

# %%
hosts[hosts.listings_owned>1].host_is_superhost.value_counts(normalize=True)
# Out:
# 0   0.69
# 1   0.31
# Name: host_is_superhost, dtype: float64

# %%
hosts[hosts.listings_owned==1].number_of_reviews.mean(),hosts[hosts.listings_owned>1].number_of_reviews.mean()
# Out:
# (26.057738095238093, 98.75)

# %% [markdown]
# ### property types of the listings
# In Seattle Airbnb market, there are predominantly listings are apartments, and the 2nd and 3rd property types are entire single houses and rooms of single houses.
#
# On the other side of street, houses did manage to obtain more average reviews than apartments, but look at the handful supply of cabins and RVs, which had 2 to 3 times more average reviews than the houses and apartments.

# %%
plotdata = listings_performance[['room_type','property_type']].copy()
plotdata['property_type'] = np.where(
    plotdata['property_type'].isin(['Apartment','House','Townhouse','Condominium']),
    plotdata['property_type'],
    'Other property type'
)
sns.catplot(
    x="property_type", 
    hue="room_type", 
    kind="count",
    palette="muted", 
    edgecolor=".6",
    data=plotdata,
    height=8,
    aspect=2
)
plt.title('Type of rooms and properties',fontsize=16);

# %%
listings_performance.host_is_superhost.value_counts()
# Out:
# f    2008
# t     667
# Name: host_is_superhost, dtype: int64

# %%
property_type_df = pd.DataFrame(
    columns = ['average_reviews','listings_count'],
    data = {
        'average_reviews' : listings_performance.groupby('property_type').number_of_reviews.mean(),
        'listings_count' : listings_performance.groupby('property_type').size()
    }
)
property_type_df.sort_values(
    by='listings_count',
    ascending=False,
    inplace=True
)
property_type_df.sort_values(by='average_reviews',ascending=False)
# Out:
#                  average_reviews  listings_count
# property_type
# Cabin                      92.57              21
# Camper/RV                  78.62               8
# Loft                       59.77              30
# Other                      44.69              16
# Bed & Breakfast            41.63              19
# House                      29.05            1201
# Apartment                  26.14            1244
# Yurt                       25.00               1
# Townhouse                  13.84              63
# Condominium                11.95              55
# Dorm                       11.00               2
# Chalet                     11.00               1
# Treehouse                  10.00               1
# Tent                        9.33               3
# Bungalow                    8.00               7
# Boat                        5.33               3

# %% [markdown]
# ## 2. Can hosting generate decent income?

# %% [markdown]
# Yes it can be. Hosts in average can expect to make somewhere around \\$11.4k a year with some of extremely successful hosts who estimated made more than \\$100k a year.
#
# In average, earning more than \\$20558 a year will get you into the top 15% club by monthly earnings. As a superhost, you would possibly be making \\$ 22285 a year.

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8), sharex=False, sharey=False)
fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)
ax = sns.scatterplot(
    x="host_since",
    y="estimated_income",
    hue='host_is_superhost',
    size='listings_owned',
    data=hosts,
    x_jitter=.01,
    sizes=(40, 400), 
    alpha=.4, 
    palette="muted"
)
ax.axhline(hosts.estimated_income.quantile(0.85), ls='--',color='gray')
ax.annotate(
    "income 85% quantile", 
    xy=(0,0), 
    xycoords="axes fraction",
    xytext=(-35,47), 
    textcoords="offset points",
    color='gray'
           )
ax.legend(frameon=True, bbox_to_anchor=(1,1))
ax.set_title('Host since(days) & Estimated incoming', fontsize=14);

# %%
round(hosts.estimated_income.median(),2), round(hosts.estimated_income.mean(),2)
# Out:
# (4928.79, 13397.13)

# %%
hosts.estimated_income.quantile(0.85)
# Out:
# 23577.272727272724

# %%
round(hosts[hosts.host_is_superhost==1].estimated_income.mean(),2)
# Out:
# 22609.05

# %% [markdown]
# Let's take a look at an "outlier" in income and a more typical earner

# %%
hosts.iloc[815][
    [
        'host_name',
        'listings_owned',  
        'estimated_income',  
        'number_of_reviews',  
        'host_since'
    ]
]
# Out:
# host_name              Daniela
# listings_owned              36
# estimated_income    609,145.45
# number_of_reviews          958
# host_since                1221
# Name: 815, dtype: object

# %% [markdown]
# host_id, listings_owned, estimated_bookings, estimated_income, number_of_reviews, host_name, host_since, host_location, host_about, host_is_superhost, host_neighbourhood, host_listings_count, host_has_profile_pic, host_identity_verified, host_in_seattle, host_count
# 815, 8534462, 36, 2, 903.03, 609, 145.45, 958, Daniela, 1221, Seattle, Washington, United States, 1, 1, Belltown, 48.00, 1, 1, 1, 1

# %% [markdown]
# ## 3. Any secrete sauce of becoming a successful host?
#
#   - assumptions:
#       - most hosts have 1 listing, so assume you would be starting with 1
#       - let's set the number of reviews as the target metric, more reviews more successful
#
#   - answer:
#       - Yes, and find more details along with the recommendations below.

# %%
one_listing_performance = listings_performance.groupby('host_id').filter(lambda x: len(x) == 1)
one_listing_performance.reset_index(drop=True,inplace=True)
one_listing_performance.host_response_time = one_listing_performance.host_response_time.replace(
    {
        'within an hour' : 0,
        'within a few hours' : 1,
        'within a day' : 2,
        'a few days or more' : 3,
        'never' : 4
    }
)
one_listing_performance.property_type = np.where(
    one_listing_performance.property_type.isin(one_listing_performance.property_type.value_counts().head(4).index),
    one_listing_performance.property_type,
    'Other')
one_listing_performance.neighbourhood_group_cleansed = one_listing_performance.neighbourhood_group_cleansed.replace('Interbay','Other neighborhoods')

one_listing_performance.bed_type = np.where(
    one_listing_performance.bed_type == 'Real Bed',
    1,
    0)


# Columns not used 
to_drop = [
    'listing_id',
    'host_id',
    'host_name',
    'host_location',
    'lat_long',
    'latitude',
    'longitude',
    'estimated_bookings',
    'estimated_income',
    'calendar_updated',
    'calendar_updated_months',
    'calendar_updated_weeks',
    'calendar_updated_days',
    'street',
    'neighbourhood',
    'reviews_per_month',
    'first_review',
    'last_review',
    'host_neighbourhood',
    'neighbourhood_cleansed',
    'zipcode'
    
]
one_listing_performance.drop(to_drop,axis=1,inplace=True)

# Columns to encoded to binary
t_f = [
    'host_is_superhost',
    'host_has_profile_pic',
    'host_identity_verified',
    'is_location_exact',
    'instant_bookable',
    'require_guest_profile_picture', 
    'require_guest_phone_verification'
]
for col in t_f:
    one_listing_performance[col].replace(
    {
        't' : 1,
        'f' : 0
    },inplace=True
)
    
# Dropping the natural language columns for now
n_l = [
    'name', 
    'summary',
    'space',
    'description'
]
one_listing_performance.host_response_rate = one_listing_performance.host_response_rate.astype(int)
one_listing_performance.drop(n_l,axis=1,inplace=True)

# Encoding categorical to numeric
n_c = [
    'neighbourhood_group_cleansed',
    'property_type',
]

one_listing_performance.room_type.replace(
{
    'Shared room' : 0,
    'Private room' : 1,
    'Entire home/apt' : 2
},inplace=True
)
enc = OneHotEncoder(handle_unknown='ignore')
enc.fit(one_listing_performance[n_c])
column_name = enc.get_feature_names()
one_hot_encoded_frame =  pd.DataFrame(enc.transform(one_listing_performance[n_c]).toarray(), columns= column_name)
one_listing_performance = pd.concat([one_listing_performance.drop(n_c,axis=1), one_hot_encoded_frame], axis=1, sort=False)
one_listing_performance.columns = one_listing_performance.columns.str.replace(r'x0','nbhd')
one_listing_performance.columns = one_listing_performance.columns.str.replace(r'x1','prop_type')
one_listing_performance.shape
# Out:
# (1680, 79)

# %%
# rearrange the order of the columns
one_listing_performance = one_listing_performance[['number_of_reviews','nights_unavailable', 'nights_available', 'estimated_price',
       'neighborhood_overview', 'notes', 'transit', 'host_since', 'host_about',
       'host_response_time', 'host_response_rate', 'host_is_superhost',
       'host_listings_count', 'host_has_profile_pic', 'host_identity_verified',
       'is_location_exact', 'room_type', 'accommodates', 'bathrooms',
       'bedrooms', 'beds', 'bed_type', 'weekly_price', 'monthly_price',
       'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
       'minimum_nights', 'maximum_nights', 'availability_30',
       'availability_60', 'availability_90', 'availability_365',
       'review_scores_rating', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value', 'instant_bookable', 'cancellation_policy',
       'require_guest_profile_picture', 'require_guest_phone_verification',
       'calculated_host_listings_count', 'amenities_counts',
       'Air Conditioning', 'Free Parking on Premises', 'Pets Allowed', 'pool',
       'Kitchen', 'host_verifications_counts', 'kba', 'jumio', 'host_in_wa',
       'distance_from_pp', 'calendar_updated_count', 'nbhd_Ballard',
       'nbhd_Beacon Hill', 'nbhd_Capitol Hill', 'nbhd_Cascade',
       'nbhd_Central Area', 'nbhd_Delridge', 'nbhd_Downtown', 'nbhd_Lake City',
       'nbhd_Magnolia', 'nbhd_Northgate', 'nbhd_Other neighborhoods',
       'nbhd_Queen Anne', 'nbhd_Rainier Valley', 'nbhd_Seward Park',
       'nbhd_University District', 'nbhd_West Seattle', 'prop_type_Apartment',
       'prop_type_Condominium', 'prop_type_House', 'prop_type_Other',
       'prop_type_Townhouse']]

# %%
plt.figure(figsize=(25,20))
corrs = one_listing_performance.corr()
sns.set(font_scale=1)
sns.set(rc={'figure.figsize':(7,7)})
hm=sns.heatmap(corrs, cbar = True, cmap="coolwarm",annot=False, square = True, fmt = '.2f')
fig = hm.get_figure()

# %%
selected = corrs.number_of_reviews[(corrs.number_of_reviews>0.20) | (corrs.number_of_reviews <-0.2)][1:]
selected[np.abs(selected).sort_values(ascending=False).index]
# Out:
# host_is_superhost                   0.33
# require_guest_phone_verification    0.33
# host_since                          0.31
# require_guest_profile_picture       0.29
# host_response_time                 -0.22
# host_about                          0.21
# Name: number_of_reviews, dtype: float64

# %% [markdown]
#   ### Any secrete sauce of becoming a successful host?
# Give the higher correlations, the following are some good moves to consider:
#     - Striving to become a "superhost"
#     - Speeding up response time to guests
#     - Making sure introducing yourself in the 'host_about'

# %%
def clean_text(df,series):
    
    df[series] = df[series].str.replace(r"[^A-Za-z0-9^,!?\.\/'+&]", " ")
    df[series] = df[series].str.replace(r"\+", " plus ")
    df[series] = df[series].str.replace(r",", " ")
    df[series] = df[series].str.replace(r"\.", " ")
    df[series] = df[series].str.replace(r"!", " ! ")
    df[series] = df[series].str.replace(r"\?", " ? ")
    df[series] = df[series].str.replace(r"'", " ")
    df[series] = df[series].str.replace(r":", " : ")
    df[series] = df[series].str.replace(r"\s{2,}", " ")
    df[series] = df[series].str.lower()
    
    return df[series]

# %%
listings_text = listings_performance[n_l]
top_15_reviews = listings_performance['number_of_reviews'].quantile(0.85)

listings_text['listing_id'] = listings_performance.listing_id
listings_text['host_is_superhost'] = listings_performance['host_is_superhost']
listings_text['host_is_superhost'].replace(
    {
        't' : 1,
        'f' : 0
    }, inplace=True
)
listings_text['number_of_reviews'] = listings_performance['number_of_reviews']
listings_text['host_has_many_reviews'] = np.where(
    listings_text['number_of_reviews'] >= top_15_reviews,
    1,
    0
)
listings_text['successful_host'] = np.where(
    listings_text['host_is_superhost'] + listings_text['host_has_many_reviews'] >=1,
    1,
    0
)
listings_text['all_text'] = listings_text['name'] + ' ' + listings_text['summary'] + ' ' + listings_text['space'] + ' ' + listings_text['description']
listings_text['all_text'] = clean_text(listings_text,'all_text')

listings_text.reset_index(drop=True,inplace=True)
listings_text = listings_text[['listing_id','all_text','successful_host']]
listings_text.head(5)
# Out:
#    listing_id                                           all_text  \
# 0        5682  cozy studio min to downtown wifi the cozy stud...
# 1        7369  launchingpad/landingpad contemporary condo on ...
# 2        9460  downtown convention ctr b&b nice ! great locat...
# 3        9531  the adorable sweet orange craftsman the sweet ...
# 4        9534  the coolest tangerine dream mil ! welcome to m...
#
#    successful_host
# 0                1
# 1                0
# 2                1
# 3                1
# 4                1

# %%
listings_vectorizer = TfidfVectorizer(
    sublinear_tf=True, 
    min_df=5, 
    norm='l2',
    ngram_range=(1,2),
    stop_words='english'
)
listings_vectors = listings_vectorizer.fit_transform(listings_text.all_text)
listings_reduced = TruncatedSVD(n_components=100, random_state=0).fit_transform(listings_vectors)
listings_embedded = TSNE(n_components=2, perplexity=40, verbose=0).fit_transform(listings_reduced)
listings_embedded = pd.DataFrame(listings_embedded)
listings_embedded['successful_host'] = listings_text.successful_host

plt.figure(figsize=(16,10))
sns.scatterplot(
    x= 0, 
    y= 1,
    hue = "successful_host",
    palette = sns.color_palette("muted",2),
    data = listings_embedded,
    legend = "full",
    alpha = 0.3
)

# %% [markdown]
# From the tf-idf visualization above, it seems hosts that have more distinctive naming and description of their listings tend to also differ the most.

# %%
rc = RandomForestClassifier(n_estimators=200, max_depth=3, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(
    listings_vectors, listings_text.successful_host, test_size=0.33, random_state=42)
rc.fit(X_train, y_train)
rc.score(X_test, y_test)
# Out:
# 0.6896942242355606

# %%
plt.figure(figsize=(16,10))
features = listings_vectorizer.get_feature_names()
importances = rc.feature_importances_
feat_importances = pd.Series(rc.feature_importances_,index=features)
feat_importances.nlargest(20).plot(kind='barh')

# %%
# Overall there are 34% of successful hosts
listings_text.successful_host.value_counts(normalize=True)
# Out:
# 0   0.66
# 1   0.34
# Name: successful_host, dtype: float64

# %%
listings_text[listings_text.all_text.str.contains('restaurants shops', case=False)].successful_host.value_counts(normalize=True)
# Out:
# 1   0.67
# 0   0.33
# Name: successful_host, dtype: float64

# %%
listings_text[listings_text.all_text.str.contains('private entrance', case=False)].successful_host.value_counts(normalize=True)
# Out:
# 1   0.52
# 0   0.48
# Name: successful_host, dtype: float64

# %%
listings_text[listings_text.all_text.str.contains('dryer iron', case=False)].successful_host.value_counts(normalize=True)
# Out:
# 1   0.76
# 0   0.24
# Name: successful_host, dtype: float64

# %%
listings_text[listings_text.all_text.str.contains('ironing board', case=False)].successful_host.value_counts(normalize=True)
# Out:
# 1   0.56
# 0   0.44
# Name: successful_host, dtype: float64

# %%
listings_text[listings_text.all_text.str.contains('coffee maker', case=False)].successful_host.value_counts(normalize=True)
# Out:
# 0   0.51
# 1   0.49
# Name: successful_host, dtype: float64

# %% [markdown]
# ### Any secrete sauce of becoming a successful host?
# Given the higher feature importances, when describing the listings, the hosts might consider doing the following:
#
#     - bragging about the amenities nearby such as restaurants and shops
#     - bragging about the amenities available on-site such as hair dryer, ironing board, and coffee maker.
#     - last but not least, guest enjoy good level of privacy, so make sure you highlight that quality. For example, mentioning that the guests will have their own private entrance, their space is free of noise from the hosts, etc.

# %%
reviews_text = reviews_imputed.merge(
    listings_performance[[
        'listing_id',
        'host_is_superhost',
        'number_of_reviews'
    ]],
    on='listing_id',
    how='inner'
)
reviews_text['host_is_superhost'].replace(
    {
        't' : 1,
        'f' : 0
    }, inplace=True
)

reviews_text['host_has_many_reviews'] = np.where(
    reviews_text['number_of_reviews'] >= top_15_reviews,
    1,
    0
)
reviews_text['successful_host'] = np.where(
    reviews_text['host_is_superhost'] + reviews_text['host_has_many_reviews'] >=1,
    1,
    0
)
reviews_text['comments'] = clean_text(reviews_text,'comments')
reviews_text = reviews_text[[
    'listing_id',
    'comments',
    'successful_host'
]]
reviews_text.reset_index(drop=True,inplace=True)
reviews_text.head()
# Out:
#    listing_id                                           comments  \
# 0     7202016  cute and cozy place perfect location to everyt...
# 1     7202016  kelly has a great room in a very central locat...
# 2     7202016  very spacious apartment and in a great neighbo...
# 3     7202016  close to seattle center and all it has to offe...
# 4     7202016  kelly was a great host and very accommodating ...
#
#    successful_host
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
reviews_vectorizer = TfidfVectorizer(
    sublinear_tf=True, 
    min_df=5, 
    norm='l2',
    ngram_range=(1,2),
    stop_words='english'
)
reviews_vectors = reviews_vectorizer.fit_transform(reviews_text.comments)
reviews_reduced = TruncatedSVD(n_components=100, random_state=0).fit_transform(reviews_vectors)
reviews_embedded = TSNE(n_components=2, perplexity=40, verbose=0).fit_transform(reviews_reduced)
reviews_embedded = pd.DataFrame(reviews_embedded)
reviews_embedded['successful_host'] = reviews_text.successful_host

plt.figure(figsize=(16,10))
sns.scatterplot(
    x= 0, 
    y= 1,
    hue = "successful_host",
    palette = sns.color_palette("muted",2),
    data = reviews_embedded,
    legend = "full",
    alpha = 0.3
)

# %% [markdown]
# From the tf-idf visualization above, it seems reviews that majority of reviews are similar for hosts with different "successful_host" status, however, (-10,-30) seems predominantly about the successful host. Another surprising problem with the Seattle Airbnb reviews is that the mostly of them are positive in sentiment. This bias has been mentioned even by Airbnb's own Data Scientist during a Data Summit (5). In another word, it is difficult to find a lot of meaningful insights from a bunch of white lies.

# %%
rc = RandomForestClassifier(n_estimators=200, max_depth=3, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(
    reviews_vectors, reviews_text.successful_host, test_size=0.33, random_state=42)
rc.fit(X_train, y_train)
rc.score(X_test, y_test)
# Out:
# 0.7209133158213781

# %%
plt.figure(figsize=(16,10))
features = reviews_vectorizer.get_feature_names()
importances = rc.feature_importances_
feat_importances = pd.Series(rc.feature_importances_,index=features)
feat_importances.nlargest(20).plot(kind='barh')

# %%
reviews_text.successful_host.value_counts(normalize=True)
# Out:
# 1   0.72
# 0   0.28
# Name: successful_host, dtype: float64

# %%
reviews_text[reviews_text.comments.str.contains('automated posting', case=False)].successful_host.value_counts(normalize=True)
# Out:
# 0   0.69
# 1   0.31
# Name: successful_host, dtype: float64

# %% [markdown]
# ### Any secrete sauce of becoming a successful host?
# This is a tricky one because overwhelmingly positive reviews on Airbnb. However, by far given the higher feature importance in reviews, it would be wise for hosts to:
#
#     - avoiding canceling reservations of clients, which would punish the host as well as trigger "automated posting" reviews in the system. (6)

# %% [markdown]
# ## Reference

# %% [markdown]
# #### (1) First name and gender dataset:
#     - https://data.world/howarder/gender-by-name
#
#
# #### (2) What amenities do guests want the most?
#     - air conditioning
#     - free parking
#     - pet-friendly
#     - pool
#     - kitchen
#     - https://news.airbnb.com/amenities-do-matter-airbnb-reveals-which-amenities-guests-search-for-most/
#
# #### (3) How many airbnb guests leave review ?
#     - about 33%
#     - shorturl.at/euxLR
#
#
# #### (4) How to become a Superhost?
#     - criteria of ratings, stays count, cancellation rate, and response rate
#     - https://www.airbnb.com/superhost
#
#
# #### (5) Airbnb positive reviews bias
#     - https://www.inc.com/laura-montini/the-psychology-of-a-positive-review-according-to-airbnb.html
#
# #### (6) "automated posting" reviews
#     - https://community.withairbnb.com/t5/Help/automated-posting/td-p/110866
